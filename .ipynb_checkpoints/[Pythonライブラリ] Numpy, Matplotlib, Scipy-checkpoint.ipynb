# %% [markdown]
# # Using Numpy, SciPy, Matplotlib

# %% [markdown]
# ### Generating a Sine Wave

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set x values(time) of the sine wave
time = np.arange(0, 10, 0.5);

# Use numpy to generate corresponding amplitude of the sine wave
amplitude   = np.sin(time)

# Plot the sine wave using time and amplitude obtained for the sine wave
plt.plot(time, amplitude)
plt.title('Sine wave')    # Plot title
plt.xlabel('Time')    # x axis label
plt.ylabel('Amplitude = sin(time)')    # y axis label
plt.grid(True, which='both')    # Configure grid lines
plt.axhline(y=0, color='k')    # Add horizontal line across the axis

# Display the sine wave
plt.show()

# %% [markdown]
# ### Integration using SciPy

# %%
import scipy.integrate as integrate
import scipy.special as special

# Differential equation integrator
result = integrate.quad(lambda x: special.jv(2.5,x), 0, 4.5)
print(result)
# Out:
# (1.1178179380783253, 7.866317216380692e-09)

# %% [markdown]
# ### Discrete Fourier Transform

# %%
import numpy as np 
from matplotlib import pyplot as plt

#Frequency in terms of Hertz
frequency  = 5 
#Sample rate
sampling_rate = 50

# Usage: numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)
time = np.linspace(0, 2, 2 * sampling_rate, endpoint = False)    # evenly spaced numbers over a specified interval
amplitude = np.sin(frequency  * 2 * np.pi * t)

figure, axis = plt.subplots()
axis.plot(time, amplitude)
axis.set_xlabel ('Time (s)')
axis.set_ylabel ('Signal amplitude')
plt.axhline(y=0, color='k')
plt.show()

# %%
from scipy import fftpack

A = fftpack.fft(amplitude)
frequency = fftpack.fftfreq(len(amplitude)) * sampling_rate

figure, axis = plt.subplots()
# Usage: stem([x,] y, linefmt=None, markerfmt=None, basefmt=None)
axis.stem(frequency, np.abs(A), use_line_collection=True)
axis.set_xlabel('Frequency in Hz')
axis.set_ylabel('Frequency Spectrum Magnitude')
axis.set_xlim(-sampling_rate / 2, sampling_rate/ 2)
axis.set_ylim(-5, 110)
plt.show()
